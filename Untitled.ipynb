# %% [markdown]
# # Health care Daata review

# %%
import pandas as pd 
import numpy as np
from bs4 import BeautifulSoup
import re
from tqdm import tqdm
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import words

# %% [markdown]
# ### Data reading

# %%
DATA = pd.read_excel("Health4Me.xlsx")

# %%
def partition(x):
    if x < 3:
        return 0
    return 1

#changing reviews with score less than 3 to be positive and vice-versa
actualScore = DATA['Rating']
positiveNegative = actualScore.map(partition) 
DATA['Rating'] = positiveNegative
print("Number of data points in our data", DATA.shape)
DATA.head(10)
# Out:
# Number of data points in our data (5215, 3)
#             User Name  Rating  \
# 0       Suzanna Smith       1
# 1  Ty'Teyania Nevings       1
# 2       Tamara Ammann       1
# 3        Timothy Long       0
# 4   Kristin Cornelius       1
# 5            LOVELY L       1
# 6         Mike Porter       0
# 7     Artricia Morgan       1
# 8        Rhonda Shult       1
# 9          Helen King       1
#
#                                      Review Comments
# 0  I love this app! Its very convenient. It has a...
# 1  I have great access to all EOB's, able to chec...
# 2  Very convenient... especially ordering prescri...
# 3  It's alright. I wish it displayed what I owe o...
# 4  great app. I love it. I love that you can view...
# 5  Just downloaded app today per CSR advise. Need...
# 6  They keep changing things... about the only co...
# 7  This app is so necessary. my wallet was stolen...
# 8  This is an update to my previous 1 star review...
# 9  This is a great app. I don't have to try and r...

# %%
DATA["Rating"].value_counts()
# Out:
# 1    2916
# 0    2299
# Name: Rating, dtype: int64

# %% [markdown]
# # Preprocessing Text Review

# %%
# https://gist.github.com/sebleier/554280
# we are removing the words from the stop words list: 'no', 'nor', 'not'
# <br /><br /> ==> after the above steps, we are getting "br br"
# we are including them into stop words list
# instead of <br /> if we have <br/> these tags would have revmoved in the 1st step

stopwords= set(['br', 'the', 'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've",\
            "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', \
            'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their',\
            'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', \
            'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', \
            'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', \
            'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after',\
            'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further',\
            'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',\
            'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', \
            's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', \
            've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn',\
            "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn',\
            "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", \
            'won', "won't", 'wouldn', "wouldn't"])

# %%
DATA["Review Comments"].to_string()
# Out:
# '0       I love this app! Its very convenient. It has a...\n1       I have great access to all EOB\'s, able to chec...\n2       Very convenient... especially ordering prescri...\n3       It\'s alright. I wish it displayed what I owe o...\n4       great app. I love it. I love that you can view...\n5       Just downloaded app today per CSR advise. Need...\n6       They keep changing things... about the only co...\n7       This app is so necessary. my wallet was stolen...\n8       This is an update to my previous 1 star review...\n9       This is a great app. I don\'t have to try and r...\n10      Love love love this app!!! This is my first in...\n11      I have tried multiple times, over multiple day...\n12      had trouble with the app, so I called the supp...\n13      The app is great for finding a nearby physicia...\n14      I am really enjoying this app! Everything is r...\n15      This app is not up to date, some of the doctor...\n16      app is out of date. providers listed are often...\n17      Hasn\'t worked for months now, across 2 differe...\n18      Access to cards offline, easy to find and see ...\n19      NO LONGER BEING SUPPORTED! PER ROBH IN United ...\n20      One stop shop for high level overview and mana...\n21      So easy to use! I can track claims for the ent...\n22      Great information ready to access and understa...\n23      this app is TOTAL GARBAGE. constant force clos...\n24      amazing app. It contains everything i need to ...\n25      I am new to UnitedHealth and its app. The app ...\n26      wonderful app, i can see detailed insurance cl...\n27      App is easy to use!! I can order and pay for m...\n28      Only supports fit it and jawbone. Somewhat lim...\n29      Its a good app. Lacks a few featurea from the ...\n30      I confirmed my email many times, still can\'t g...\n31      it holds information you might need when you v...\n32      it\'s very easy to add your cards on the app. I...\n33      "sorry you are unable to use this app right no...\n34      I like that I can reference basic questions wi...\n35      very user-friendly could use a little more inf...\n36      this app is so useful. to. do mostly what I wo...\n37      So far so good. Very intuitive, information wi...\n38      It isn\'t providing any feature information.I a...\n39      Enjoying being able to have my medical history...\n40      I love this appt. Knowing how much you have to...\n41      Love this app. Wish it had a link to the depen...\n42      im still learning my way around the app and un...\n43       very secure app. quite helpful. i like it a lot.\n44      great help to me for login and password for lo...\n45      opened ap, keyboard for it doesnt even come up...\n46      Super easy to navigate and I get all the infor...\n47                 its honestly detailed. and i love that\n48      Great app! All the information I need to manag...\n49      easy & updated. makes tracking my benefits easier\n50      Great app! Helps keep all my insurance in one ...\n51      it\'s great everything I need to know is at my ...\n52      the best app ever! All of you healthcare needs...\n53        great app. easy to navigate. useful information\n54      The app is very convenient, however, I can onl...\n55      excellent app to help you with your health car...\n56      Great App. It\'s allows me to gain control of m...\n57      keep sending me to the wrong doctors you have ...\n58      This app is the worst. I can\'t download my ins...\n59      information i get for prices on my prescriptio...\n60      The app is intuitive, easy to navigate. I wish...\n61                     The app is trash and so is United.\n62      good app- could have designed better for ease ...\n63      so convenient! always has the information i ne...\n64      I get ZERO results for doctors in the app if t...\n65      easy way to see what\'s going on with your insu...\n66      This application is worthless. Things you can ...\n67      Very good app working with  ...

# %%
from tqdm import tqdm
preprocessed_reviews = []
# tqdm is for printing the status bar
for sentance in tqdm(DATA['Review Comments']):
    sentance = str(sentance)
    sentance = BeautifulSoup(sentance, 'lxml').get_text()
    sentance = re.sub("\S*\d\S*", "", sentance).strip()
    sentance = re.sub('[^A-Za-z]+', ' ', sentance)
    # https://gist.github.com/sebleier/554280
    sentance = ' '.join(e.lower() for e in sentance.split() if e.lower() not in stopwords)
    preprocessed_reviews.append(sentance.strip())
# Out:
# 100%|██████████| 5215/5215 [00:01<00:00, 3862.74it/s]

# %%
preprocessed_reviews[0:5]
# Out:
# ['love app convenient basic stuff need see go desktop version need detailed view',
#  'great access eob able check health savings account visits processed like access check insurance benefits right hand',
#  'convenient especially ordering prescription refills little glitchy first installed everything seems work consistently',
#  'alright wish displayed owe home screen instead go every claim also get fitbit sync work best expressed simple word problem q stride length approximately feet login grant permission see device full review',
#  'great app love love view deductible pocket maximum awesome app']

# %%
#from sklearn.cross_validation import 
from sklearn.linear_model import LogisticRegression
#from sklearn.cross_validation import cross_val_score
from collections import Counter
import collections
from sklearn.metrics import accuracy_score,roc_auc_score,roc_curve,confusion_matrix,auc
#from sklearn import cross_validation
from scipy.sparse import csr_matrix,hstack
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.model_selection import train_test_split 
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score,roc_auc_score,roc_curve,confusion_matrix,auc
from sklearn.naive_bayes import MultinomialNB

# %%
X_1, X_test, y_1, y_test = train_test_split(preprocessed_reviews,DATA['Rating'], test_size=0.2, random_state=0)
X_tr, X_cv, y_tr, y_cv = train_test_split(X_1, y_1, test_size=0.2)
print(np.asarray(X_1).shape,np.asarray(X_test).shape,np.asarray(X_tr).shape,np.asarray(X_test).shape,np.asarray(X_cv).shape)
# Out:
# (4172,) (1043,) (3337,) (1043,) (835,)

# %% [markdown]
# ## Featurization

# %% [markdown]
# ### Bag Of Words

# %%
#BoW
count_vect = CountVectorizer() #in scikit-learn
BOW_Train = count_vect.fit_transform(X_tr)
BOW_test = count_vect.transform(X_test)
BOW_CV = count_vect.transform(X_cv)
print("some feature names ", count_vect.get_feature_names()[:10])
print('='*50)
print("the type of count vectorizer ",type(BOW_Train))
print("the shape of out text BOW vectorizer ",BOW_Train.get_shape())
print("the number of unique words ", BOW_Train.get_shape()[1])
# Out:
# some feature names  ['aarp', 'ability', 'able', 'absolute', 'absolutely', 'accect', 'accees', 'accept', 'accepted', 'accepting']
# ==================================================
# the type of count vectorizer  <class 'scipy.sparse.csr.csr_matrix'>
# the shape of out text BOW vectorizer  (3337, 3137)
# the number of unique words  3137

# %% [markdown]
# ### TFIDF

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer


tf_idf_vect = TfidfVectorizer(ngram_range=(1,2), min_df=10)
TFIDF_Train = tf_idf_vect.fit_transform(X_tr)
TFIDF_Test = tf_idf_vect.transform(X_test)
TFIDF_Validation = tf_idf_vect.transform(X_cv)
print("the type of count vectorizer ",type(TFIDF_Train))
print("the shape of out text TFIDF vectorizer ",TFIDF_Train.get_shape())
print("the number of unique words including both unigrams and bigrams ", TFIDF_Train.get_shape()[1])
# Out:
# the type of count vectorizer  <class 'scipy.sparse.csr.csr_matrix'>
# the shape of out text TFIDF vectorizer  (3337, 643)
# the number of unique words including both unigrams and bigrams  643

# %% [markdown]
# ### Naive Bayes

# %%
alph = [10**(-3),10**(-2),10**(-1),1,10,100,1000]
BOW_Train_Accuracy = []
BOW_CV_Accuracy = []
for i in alph:
    model = MultinomialNB(alpha=i)
    model.fit(BOW_Train,y_tr)
    train_pred = model.predict_log_proba(BOW_Train)[:,1]
    val_pred=model.predict_log_proba(BOW_CV)[:,1]
    BOW_Train_Accuracy.append(roc_auc_score(np.asarray(y_tr),np.asarray(train_pred)))
    BOW_CV_Accuracy.append(roc_auc_score(np.asarray(y_cv),np.asarray(val_pred)))

    
plt.plot(np.log(np.asarray(alph)), BOW_Train_Accuracy, label='Train AUC')
plt.plot(np.log(np.asarray(alph)), BOW_CV_Accuracy, label='CV AUC')
plt.legend()
plt.xlabel("alpha: hyperparameter")
plt.ylabel("AUC")
plt.title("ERROR PLOTS")
plt.show()

# %%
best_alpha = 100

# %% [markdown]
# ### Testing on test data

# %%
model = MultinomialNB(alpha=best_alpha)
model.fit(BOW_Train,y_tr)
test_pred = model.predict_log_proba(BOW_test)[:,1]
train_pred =model.predict_log_proba(BOW_Train)[:,1]
train_fpr, train_tpr, thresholds = roc_curve(y_tr, train_pred)
test_fpr, test_tpr, thresholds = roc_curve(y_test, test_pred)

plt.plot(train_fpr, train_tpr, label="train AUC ="+str(auc(train_fpr, train_tpr)))
plt.plot(test_fpr, test_tpr, label="test AUC ="+str(auc(test_fpr, test_tpr)))
plt.plot([0.0,1.0],[0.0,1.0])
plt.legend()
plt.xlabel("K: hyperparameter")
plt.ylabel("AUC")
plt.title("ERROR PLOTS")
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
ytrain = model.predict(BOW_Train)
ytest = model.predict(BOW_test)
ctrain = confusion_matrix(y_tr,ytrain)
ctest = confusion_matrix(y_test,ytest)
class_label=["No","Yes"]
df = pd.DataFrame(ctest, index=class_label, columns=class_label)
sns.heatmap(df, annot= True, fmt="d", cmap="YlGnBu")

# %% [markdown]
# # Logistic regression using l2 regularizer

# %% [markdown]
# # BOW

# %%
lamda= [10**(-4),10**(-3),10**(-2),10**(-1),1,10,100,1000,10000]
BOW_val_accuracy = []
BOW_train_accuracy = []
for i in lamda:
    model = LogisticRegression(C=i,penalty='l2')
    model.fit(BOW_Train,y_tr)
    val_data  = model.predict_log_proba(BOW_CV)[:,1]
    train_data = model.predict_log_proba(BOW_Train)[:,1]
    BOW_val_accuracy.append(roc_auc_score(np.asarray(y_cv),np.asarray(val_data)))
    BOW_train_accuracy.append(roc_auc_score(np.asarray(y_tr),np.asarray(train_data)))
plt.plot(np.log(np.asarray(lamda)), BOW_train_accuracy, label='Train AUC')
plt.plot(np.log(np.asarray(lamda)), BOW_val_accuracy, label='CV AUC')
plt.legend()
plt.xlabel("alpha: hyperparameter")
plt.ylabel("AUC")
plt.title("ERROR PLOTS")
plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:1681: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.predict_proba(X))
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:1681: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.predict_proba(X))
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:1681: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.predict_proba(X))

# %%
best_lambda=1

# %% [markdown]
# ### Testing on test data

# %%
model = LogisticRegression(C=best_lambda,penalty='l1')
model.fit(BOW_Train,y_tr)
test_pred  = model.predict_log_proba(BOW_test)[:,1]
train_pred = model.predict_log_proba(BOW_Train)[:,1]
train_fpr, train_tpr, thresholds = roc_curve(y_tr, train_pred)
test_fpr, test_tpr, thresholds = roc_curve(y_test, test_pred)

plt.plot(train_fpr, train_tpr, label="train AUC ="+str(auc(train_fpr, train_tpr)))
plt.plot(test_fpr, test_tpr, label="test AUC ="+str(auc(test_fpr, test_tpr)))
plt.plot([0.0,1.0],[0.0,1.0])
plt.legend()
plt.xlabel("alpha: hyperparameter")
plt.ylabel("AUC")
plt.title("ERROR PLOTS")
plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# ### Positive features

# %%
a = model.coef_
b= []
for i in range(3137):
    if a[0][i]>0:
        b.append((i,a[0][i]))
b =  sorted(b,key= lambda x: x[1],reverse=True)
b = b[0:50]
print(b)
print(" So the top 50 features of positive class are--")
for i in range(0,50):
    print("feature name : %s , value : %f"%(count_vect.get_feature_names()[b[i][0]],b[i][1]))
# Out:
# [(1578, 4.177948134593984), (785, 3.7440136336413965), (182, 3.37164538808295), (2575, 2.9441816834435444), (518, 2.8241088163933417), (1143, 2.7832905297383395), (624, 2.7603785975363597), (881, 2.328654947355547), (1132, 2.327023813940398), (991, 2.299748574747601), (1214, 2.155672907435334), (1832, 2.0912667454061418), (783, 2.0111816543807306), (1823, 1.9920682266063592), (1771, 1.960395230198965), (1913, 1.9545161081608897), (1940, 1.7714928605973221), (1217, 1.6447345696695606), (1492, 1.5983517906298812), (1508, 1.5737904172276662), (378, 1.5522548078472111), (83, 1.5318869592242699), (1257, 1.4969749872640032), (1838, 1.4893755715010701), (994, 1.4810512201726502), (943, 1.418188992912814), (525, 1.3863157974960194), (2140, 1.3164899671091468), (1136, 1.3020732495708507), (2952, 1.2791722795337361), (614, 1.2651625608564034), (2229, 1.264236627746672), (320, 1.2050257571804366), (2207, 1.2039989273461613), (987, 1.08278547055559), (135, 1.0674321712488315), (257, 1.055803353695459), (2638, 1.051716557065459), (93, 1.0154712261659389), (681, 0.9944942974187255), (1346, 0.9927537345613304), (236, 0.9834410296291912), (1478, 0.9556110043844589), (1789, 0.9326140808419731), (3078, 0.9241212713303031), (671, 0.8910666777717411), (2750, 0.884842085578367), (2851, 0.8823096591430937), (1308, 0.8683070106136854), (1062, 0.8650809012829946)]
#  So the top 50 features of positive class are--
# feature name : love , value : 4.177948
# feature name : easy , value : 3.744014
# feature name : awesome , value : 3.371645
# feature name : specialist , value : 2.944182
# feature name : convenient , value : 2.824109
# feature name : great , value : 2.783291
# feature name : definitely , value : 2.760379
# feature name : excellent , value : 2.328655
# feature name : good , value : 2.327024
# feature name : fingerprint , value : 2.299749
# feature name : helpful , value : 2.155673
# feature name : ok , value : 2.091267
# feature name : easier , value : 2.011182
# feature name : office , value : 1.992068
# feature name : nice , value : 1.960395
# feature name : passwords , value : 1.954516
# feature name : perfect , value : 1.771493
# feature name : helps , value : 1.644735
# feature name : left , value : 1.598352
# feature name : like , value : 1.573790
# feature name : check , value : 1.552255
# feature name : along , value : 1.531887
# feature name : however , value : 1.496975
# feature name : online , value : 1.489376
# feature name : fingertips , value : 1.481051
# feature name : far , value : 1.418189
# feature name : cool , value : 1.386316
# feature name : quick , value : 1.316490
# feature name : got , value : 1.302073
# feature name : useful , value : 1.279172
# feature name : decent , value : 1.265163
# feature name : reinstall , value : 1.264237
# feature name : cabinet , value : 1.205026
# feature name : refill , value : 1.203999
# feature name : fine , value : 1.082785
# feature name : appt , value : 1.067432
# feature name : bit , value : 1.055803
# feature name : straight , value : 1.051717
# feature name : amazing , value : 1.015471
# feature name : devices , value : 0.994494
# feature name : informative , value : 0.992754
# feature name : best , value : 0.983441
# feature name : later , value : 0.955611
# feature name : notification , value : 0.932614
# feature name : wonderful , value : 0.924121
# feature name : details , value : 0.891067
# feature name : thank , value : 0.884842
# feature name : turned , value : 0.882310
# feature name : improved , value : 0.868307
# feature name : friendly , value : 0.865081

# %%
c=[]
for i in range(0,50):
    c.append(count_vect.get_feature_names()[b[i][0]])
from wordcloud import WordCloud
wordcloud = WordCloud(
                          background_color='white',
                          max_words=50,
                          max_font_size=50, 
                          random_state=50
                         ).generate(str(c))

fig = plt.figure(1,figsize=(12,18))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Negative features

# %%
a = model.coef_
b= []
for i in range(3137):
    if a[0][i]<0:
        b.append((i,a[0][i]))
b =  sorted(b,key= lambda x: x[1])
b = b[0:100]
print(b)
print(" So the top 100 features of negative class are--")
for i in range(0,100):
    print("feature name : %s , value : %f"%(count_vect.get_feature_names()[b[i][0]],b[i][1]))
# Out:
# [(1775, -3.6539173971733767), (2954, -3.203689109619022), (3092, -3.0275250720650666), (3095, -2.58695892915719), (1656, -2.5475361793743776), (2906, -2.4972926705178145), (2908, -2.366122912308804), (2743, -2.3100418329621237), (1188, -2.148776919459162), (3020, -2.134754880619885), (865, -2.028369132811554), (1564, -2.0157543119504506), (2670, -1.9916926235559635), (2222, -1.9905527824790188), (2878, -1.9026955344177654), (3093, -1.7606493435486374), (1782, -1.7541941966781334), (3082, -1.7350049047628429), (1585, -1.7297274460828416), (750, -1.702566793267935), (2291, -1.6970677378146757), (3036, -1.6307846364518), (678, -1.6175067242156955), (1893, -1.5866892287965892), (922, -1.5386003696201525), (1662, -1.4836263170481316), (2845, -1.476306919982723), (516, -1.4727540352620803), (1765, -1.4709910077847317), (2631, -1.4612007719712055), (2632, -1.4541901316857413), (513, -1.426220854171941), (562, -1.4105235194493644), (558, -1.3962880323877345), (2513, -1.3886778823363706), (1713, -1.3834192441135522), (3106, -1.3353635987809507), (108, -1.3285389739732858), (184, -1.2997855153500495), (930, -1.2997618988221353), (106, -1.285809656730563), (458, -1.2516628351511596), (1553, -1.2503156981428472), (2105, -1.2493170996900456), (2605, -1.24436682344125), (2176, -1.2389473018997705), (563, -1.2266498338380134), (311, -1.2242471921940936), (2489, -1.2164311093978535), (748, -1.2057298002793337), (564, -1.2037723014874986), (1059, -1.2037593384301606), (1835, -1.1962704316358417), (1499, -1.1791852753263639), (81, -1.1715287348025714), (3132, -1.1712090181691135), (1547, -1.169005065079371), (2380, -1.1682011830741466), (888, -1.1262589305379362), (1912, -1.1116939398760932), (2219, -1.1025217264162417), (1033, -1.0626340359034858), (1248, -1.0602507310004234), (1711, -1.051560522615696), (794, -0.9950088993676395), (1304, -0.993774830996646), (1550, -0.9883572949545082), (3044, -0.9770009355948457), (2015, -0.9588831005141409), (1071, -0.9556798786314931), (1105, -0.9486821517415265), (2014, -0.9433300823724005), (1781, -0.9421300701178766), (3033, -0.9385588582657574), (2836, -0.9325090784664659), (1804, -0.928145452559085), (2947, -0.9207462504611462), (1560, -0.9200179254771481), (2735, -0.9165650323533554), (1055, -0.9024815736094913), (797, -0.8647630346595698), (1841, -0.8641827902275235), (1738, -0.8600132794836425), (97, -0.8416420801502787), (1521, -0.829773189801163), (717, -0.8125744019729116), (2854, -0.7958066263068828), (502, -0.762625330428562), (2444, -0.7497959680408162), (161, -0.7491774142785743), (1617, -0.7350887373672349), (1770, -0.7346518517445668), (1420, -0.7110610559765644), (1186, -0.708892746700188), (464, -0.7088885856266759), (505, -0.706173937843467), (3098, -0.7024335983483588), (2933, -0.7012624676202243), (111, -0.6908546040091632), (2428, -0.6737687846930897)]
#  So the top 100 features of negative class are--
# feature name : none , value : -3.653917
# feature name : useless , value : -3.203689
# feature name : worse , value : -3.027525
# feature name : worthless , value : -2.586959
# feature name : members , value : -2.547536
# feature name : uninstalled , value : -2.497293
# feature name : uninstalling , value : -2.366123
# feature name : terrible , value : -2.310042
# feature name : hate , value : -2.148777
# feature name : waste , value : -2.134755
# feature name : even , value : -2.028369
# feature name : looks , value : -2.015754
# feature name : sucks , value : -1.991693
# feature name : registration , value : -1.990553
# feature name : unable , value : -1.902696
# feature name : worst , value : -1.760649
# feature name : note , value : -1.754194
# feature name : work , value : -1.735005
# feature name : luck , value : -1.729727
# feature name : downloaded , value : -1.702567
# feature name : resolution , value : -1.697068
# feature name : weeks , value : -1.630785
# feature name : developers , value : -1.617507
# feature name : pain , value : -1.586689
# feature name : facilities , value : -1.538600
# feature name : menu , value : -1.483626
# feature name : try , value : -1.476307
# feature name : control , value : -1.472754
# feature name : never , value : -1.470991
# feature name : stopped , value : -1.461201
# feature name : stopping , value : -1.454190
# feature name : continues , value : -1.426221
# feature name : crashed , value : -1.410524
# feature name : crap , value : -1.396288
# feature name : since , value : -1.388678
# feature name : months , value : -1.383419
# feature name : wrong , value : -1.335364
# feature name : anything , value : -1.328539
# feature name : awful , value : -1.299786
# feature name : failure , value : -1.299762
# feature name : anymore , value : -1.285810
# feature name : compatible , value : -1.251663
# feature name : logon , value : -1.250316
# feature name : provide , value : -1.249317
# feature name : start , value : -1.244367
# feature name : reason , value : -1.238947
# feature name : crashes , value : -1.226650
# feature name : bugs , value : -1.224247
# feature name : shut , value : -1.216431
# feature name : download , value : -1.205730
# feature name : crashing , value : -1.203772
# feature name : frequently , value : -1.203759
# feature name : older , value : -1.196270
# feature name : let , value : -1.179185
# feature name : almost , value : -1.171529
# feature name : zero , value : -1.171209
# feature name : log , value : -1.169005
# feature name : saying , value : -1.168201
# feature name : exist , value : -1.126259
# feature name : password , value : -1.111694
# feature name : register , value : -1.102522
# feature name : force , value : -1.062634
# feature name : horrible , value : -1.060251
# feature name : month , value : -1.051561
# feature name : effort , value : -0.995009
# feature name : impossible , value : -0.993775
# feature name : login , value : -0.988357
# feature name : went , value : -0.977001
# feature name : poorly , value : -0.958883
# feature name : frustrating , value : -0.955680
# feature name : gets , value : -0.948682
# feature name : poor , value : -0.943330
# feature name : not , value : -0.942130
# feature name : website , value : -0.938559
# feature name : tried , value : -0.932509
# feature name : obamacare , value : -0.928145
# feature name : usability , value : -0.920746
# feature name : longer , value : -0.920018
# feature name : telling , value : -0.916565
# feature name : freezes , value : -0.902482
# feature name : either , value : -0.864763
# feature name : open , value : -0.864183
# feature name : name , value : -0.860013
# feature name : android , value : -0.841642
# feature name : list , value : -0.829773
# feature name : display , value : -0.812574
# feature name : twice , value : -0.795807
# feature name : constantly , value : -0.762625
# feature name : sends , value : -0.749796
# feature name : ate , value : -0.749177
# feature name : many , value : -0.735089
# feature name : nexus , value : -0.734652
# feature name : joke , value : -0.711061
# feature name : hardly , value : -0.708893
# feature name : complete , value : -0.708889
# feature name : contacts , value : -0.706174
# feature name : would , value : -0.702434
# feature name : upgrade , value : -0.701262
# feature name : anywhere , value : -0.690855
# feature name : seemed , value : -0.673769

# %%
c=[]
for i in range(0,50):
    c.append(count_vect.get_feature_names()[b[i][0]])
from wordcloud import WordCloud
wordcloud = WordCloud(
                          background_color='white',
                          max_words=100,
                          max_font_size=30, 
                          random_state=50
                         ).generate(str(c))

fig = plt.figure(1,figsize=(20,20))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# # Tfidf

# %%
lamda= [10**(-4),10**(-3),10**(-2),10**(-1),1,10,100,1000,10000]
tfidf_val_accuracy = []
tfidf_train_accuracy = []
for i in lamda:
    model = LogisticRegression(C=i,penalty='l2')
    model.fit(TFIDF_Train,y_tr)
    val_data  = model.predict_log_proba(TFIDF_Validation)[:,1]
    train_data = model.predict_log_proba(TFIDF_Train)[:,1]
    tfidf_val_accuracy.append(roc_auc_score(np.asarray(y_cv),np.asarray(val_data)))
    tfidf_train_accuracy.append(roc_auc_score(np.asarray(y_tr),np.asarray(train_data)))
plt.plot(np.log(np.asarray(lamda)), tfidf_train_accuracy, label='Train AUC')
plt.plot(np.log(np.asarray(lamda)), tfidf_val_accuracy, label='CV AUC')
plt.legend()
plt.xlabel("alpha: hyperparameter")
plt.ylabel("AUC")
plt.title("ERROR PLOTS")
plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:1681: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.predict_proba(X))
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:1681: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.predict_proba(X))

# %%
best_lambda =1

# %%
model = LogisticRegression(C=best_lambda,penalty='l2')
model.fit(TFIDF_Train,y_tr)
test_pred  = model.predict_log_proba(TFIDF_Test)[:,1]
train_pred = model.predict_log_proba(TFIDF_Train)[:,1]
train_fpr, train_tpr, thresholds = roc_curve(y_tr, train_pred)
test_fpr, test_tpr, thresholds = roc_curve(y_test, test_pred)

plt.plot(train_fpr, train_tpr, label="train AUC ="+str(auc(train_fpr, train_tpr)))
plt.plot(test_fpr, test_tpr, label="test AUC ="+str(auc(test_fpr, test_tpr)))
plt.plot([0.0,1.0],[0.0,1.0])
plt.legend()
plt.xlabel("alpha: hyperparameter")
plt.ylabel("AUC")
plt.title("ERROR PLOTS")
plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# ### confusion Matrix

# %%
ytrain = model.predict(TFIDF_Train)
ytest = model.predict(TFIDF_Test)
ctrain = confusion_matrix(y_tr,ytrain)
ctest = confusion_matrix(y_test,ytest)
class_label=["No","Yes"]
df = pd.DataFrame(ctest, index=class_label, columns=class_label)
sns.heatmap(df, annot= True, fmt="d", cmap="YlGnBu")

# %% [markdown]
# ### Positive features

# %%
# Please write all the code with proper documentation
a = model.coef_
b= []
for i in range(643):
    if a[0][i]>0:
        b.append((i,a[0][i]))
b =  sorted(b,key= lambda x: x[1],reverse=True)
b = b[0:50]
print(b)
print(" So the top 50 features of positive class are--")
for i in range(0,50):
    print("feature name : %s , value : %f"%(tf_idf_vect.get_feature_names()[b[i][0]],b[i][1]))
# Out:
# [(153, 4.7908596202496385), (237, 4.31343837978165), (326, 3.816698557400285), (232, 2.971106491313237), (248, 2.673503762831823), (55, 2.6044228222185866), (108, 2.430096887145209), (375, 2.424269540552517), (300, 1.9705879491132003), (238, 1.89073749424661), (591, 1.8456540131257018), (396, 1.8028098399098396), (156, 1.7794859197696382), (185, 1.7453764013474233), (177, 1.7002182511779256), (250, 1.5444047662625549), (151, 1.4949447902538313), (174, 1.4573125626353345), (63, 1.439489719903969), (417, 1.3900138796699146), (233, 1.3867058990446401), (88, 1.3545164697174117), (109, 1.3441843419243753), (86, 1.341616080048421), (559, 1.3336135669320421), (452, 1.3184626782565736), (257, 1.227350825903841), (20, 1.1882630164545656), (272, 1.1744009645335574), (505, 1.1602395580216909), (596, 1.1466978223811846), (544, 1.1429480898667654), (199, 1.11565732644521), (240, 1.1083082615067783), (627, 1.1035340162661782), (327, 1.091203163251152), (130, 1.009162080327107), (204, 0.9667816023126028), (394, 0.9530300102500526), (243, 0.9161712492316805), (363, 0.9129909277648522), (440, 0.8869054305500375), (187, 0.8797426763474787), (135, 0.8554768615384886), (342, 0.8324475922425225), (398, 0.8241543500447539), (276, 0.8054257546288254), (454, 0.8034897582409406), (178, 0.7863764191522999), (415, 0.7736569889409988)]
#  So the top 50 features of positive class are--
# feature name : easy , value : 4.790860
# feature name : great , value : 4.313438
# feature name : love , value : 3.816699
# feature name : good , value : 2.971106
# feature name : helpful , value : 2.673504
# feature name : awesome , value : 2.604423
# feature name : convenient , value : 2.430097
# feature name : nice , value : 2.424270
# feature name : like , value : 1.970588
# feature name : great app , value : 1.890737
# feature name : useful , value : 1.845654
# feature name : ok , value : 1.802810
# feature name : easy use , value : 1.779486
# feature name : far , value : 1.745376
# feature name : excellent , value : 1.700218
# feature name : helps , value : 1.544405
# feature name : easier , value : 1.494945
# feature name : everything , value : 1.457313
# feature name : best , value : 1.439490
# feature name : perfect , value : 1.390014
# feature name : good app , value : 1.386706
# feature name : claims , value : 1.354516
# feature name : cool , value : 1.344184
# feature name : check , value : 1.341616
# feature name : track , value : 1.333614
# feature name : quick , value : 1.318463
# feature name : however , value : 1.227351
# feature name : amazing , value : 1.188263
# feature name : informative , value : 1.174401
# feature name : simple , value : 1.160240
# feature name : user friendly , value : 1.146698
# feature name : thank , value : 1.142948
# feature name : fingertips , value : 1.115657
# feature name : handy , value : 1.108308
# feature name : works well , value : 1.103534
# feature name : love app , value : 1.091203
# feature name : decent , value : 1.009162
# feature name : fixed , value : 0.966782
# feature name : office , value : 0.953030
# feature name : health , value : 0.916171
# feature name : need , value : 0.912991
# feature name : problems , value : 0.886905
# feature name : fast , value : 0.879743
# feature name : details , value : 0.855477
# feature name : medical , value : 0.832448
# feature name : one , value : 0.824154
# feature name : insurance , value : 0.805426
# feature name : quickly , value : 0.803490
# feature name : excellent app , value : 0.786376
# feature name : payments , value : 0.773657

# %%
c=[]
for i in range(0,50):
    c.append(tf_idf_vect.get_feature_names()[b[i][0]])
from wordcloud import WordCloud
wordcloud = WordCloud(
                          background_color='white',
                          max_words=50,
                          max_font_size=50, 
                          random_state=50
                         ).generate(str(c))

fig = plt.figure(1,figsize=(12,18))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Negative features

# %%
a = model.coef_
b= []
for i in range(643):
    if a[0][i]>0:
        b.append((i,a[0][i]))
b =  sorted(b,key= lambda x: x[1])
b = b[0:100]
print(b)
print(" So the top 100 features of positive class are--")
for i in range(0,100):
    print("feature name : %s , value : %f"%(tf_idf_vect.get_feature_names()[b[i][0]],b[i][1]))
# Out:
# [(224, 0.002762394793038479), (51, 0.003584222030012141), (590, 0.007157452006307149), (580, 0.007503458588499012), (362, 0.014104746027766698), (414, 0.02424987662508336), (380, 0.02511096886484269), (252, 0.02551427632885919), (541, 0.026935311589978327), (528, 0.02913698792210004), (635, 0.032141642086675574), (420, 0.03257800291216921), (201, 0.03299574929481246), (92, 0.038086870110513434), (234, 0.038759433002557915), (184, 0.043441100682919565), (103, 0.05098974792387204), (244, 0.05755476678179798), (366, 0.05778898440081467), (286, 0.06545523101991156), (365, 0.06900268377026958), (295, 0.0691325310706264), (405, 0.06944398364879706), (90, 0.07380736712958279), (219, 0.07772829634373904), (270, 0.08291400039932326), (253, 0.08474959036183861), (321, 0.08637367454395266), (221, 0.08987378019182951), (27, 0.09346162848505143), (114, 0.09646169879585621), (638, 0.10266893181096047), (433, 0.10526242826126704), (113, 0.10579445638719695), (322, 0.11021431642240181), (634, 0.11271990099222856), (58, 0.11275493886799932), (127, 0.11422237772409194), (12, 0.11568683566184665), (164, 0.11944839030931881), (180, 0.1209333193115591), (534, 0.12157538127909541), (76, 0.12175432594526159), (9, 0.12431942077916724), (538, 0.125257132447547), (282, 0.12893318057933223), (14, 0.1436546509688433), (150, 0.14416858608474), (239, 0.14430316061947432), (447, 0.1485982358053023), (293, 0.14894202182560226), (451, 0.1493213361830417), (142, 0.15047292182994096), (535, 0.1508326068674528), (554, 0.1554286991263997), (445, 0.15646587928826672), (226, 0.16355001320144288), (328, 0.16375370471931838), (330, 0.16527608942779046), (280, 0.16644848950302898), (6, 0.16773488825479801), (556, 0.1693299779053073), (230, 0.17052660849611873), (144, 0.17063661863708862), (493, 0.17246567791938885), (33, 0.17551381277939274), (18, 0.17591883302140993), (278, 0.1765307801372948), (49, 0.17729421113290647), (501, 0.18109291797277222), (138, 0.18988424078465047), (557, 0.19319846831519213), (343, 0.193274471830211), (189, 0.19396863226704836), (256, 0.1977220952671063), (402, 0.20585123462892738), (425, 0.20896712688458774), (149, 0.21504187326919524), (626, 0.21688594721852336), (587, 0.21932065408104354), (329, 0.22060510170129222), (188, 0.22150275492077445), (264, 0.22271245203920395), (574, 0.2232335091598325), (516, 0.22664642535724464), (39, 0.22709388439947256), (200, 0.22870818584692795), (136, 0.23219714232148228), (66, 0.23348545341776855), (393, 0.23419363991924924), (336, 0.2365526979585093), (494, 0.23871470919074114), (307, 0.24598478488289036), (461, 0.24707694176905373), (304, 0.25831519169129397), (168, 0.25839363697683576), (490, 0.26171239283263714), (277, 0.2623987795536955), (50, 0.26569317993692554), (11, 0.2692179634648146)]
#  So the top 100 features of positive class are--
# feature name : getting , value : 0.002762
# feature name : ask , value : 0.003584
# feature name : used , value : 0.007157
# feature name : united healthcare , value : 0.007503
# feature name : near , value : 0.014105
# feature name : pay , value : 0.024250
# feature name : no matter , value : 0.025111
# feature name : home , value : 0.025514
# feature name : tells , value : 0.026935
# feature name : stops working , value : 0.029137
# feature name : would not , value : 0.032142
# feature name : phone number , value : 0.032578
# feature name : first time , value : 0.032996
# feature name : close , value : 0.038087
# feature name : google , value : 0.038759
# feature name : family , value : 0.043441
# feature name : computer , value : 0.050990
# feature name : health care , value : 0.057555
# feature name : needs work , value : 0.057789
# feature name : keep , value : 0.065455
# feature name : needs , value : 0.069003
# feature name : later , value : 0.069133
# feature name : others , value : 0.069444
# feature name : clear , value : 0.073807
# feature name : gave , value : 0.077728
# feature name : information , value : 0.082914
# feature name : hope , value : 0.084750
# feature name : look , value : 0.086374
# feature name : get info , value : 0.089874
# feature name : anytime , value : 0.093462
# feature name : costs , value : 0.096462
# feature name : years , value : 0.102669
# feature name : prescription , value : 0.105262
# feature name : cost , value : 0.105794
# feature name : looking , value : 0.110214
# feature name : would nice , value : 0.112720
# feature name : bad , value : 0.112755
# feature name : date , value : 0.114222
# feature name : address , value : 0.115687
# feature name : entire , value : 0.119448
# feature name : extremely , value : 0.120933
# feature name : supposed , value : 0.121575
# feature name : called , value : 0.121754
# feature name : accurate , value : 0.124319
# feature name : tech , value : 0.125257
# feature name : issue , value : 0.128933
# feature name : allows , value : 0.143655
# feature name : due , value : 0.144169
# feature name : great easy , value : 0.144303
# feature name : providers , value : 0.148598
# feature name : know , value : 0.148942
# feature name : questions , value : 0.149321
# feature name : doctors , value : 0.150473
# feature name : sure , value : 0.150833
# feature name : times , value : 0.155429
# feature name : provided , value : 0.156466
# feature name : gives , value : 0.163550
# feature name : love easy , value : 0.163754
# feature name : made , value : 0.165276
# feature name : intuitive , value : 0.166448
# feature name : access , value : 0.167735
# feature name : tool , value : 0.169330
# feature name : goes , value : 0.170527
# feature name : done , value : 0.170637
# feature name : seems , value : 0.172466
# feature name : app great , value : 0.175514
# feature name : also , value : 0.175919
# feature name : insurance cards , value : 0.176531
# feature name : area , value : 0.177294
# feature name : several , value : 0.181093
# feature name : different , value : 0.189884
# feature name : top , value : 0.193198
# feature name : meds , value : 0.193274
# feature name : feature , value : 0.193969
# feature name : hours , value : 0.197722
# feature name : option , value : 0.205851
# feature name : plans , value : 0.208967
# feature name : dr , value : 0.215042
# feature name : works great , value : 0.216886
# feature name : use , value : 0.219321
# feature name : loved , value : 0.220605
# feature name : fax , value : 0.221503
# feature name : im , value : 0.222712
# feature name : understand , value : 0.223234
# feature name : stars , value : 0.226646
# feature name : app says , value : 0.227094
# feature name : first , value : 0.228708
# feature name : device , value : 0.232197
# feature name : bill , value : 0.233485
# feature name : numbers , value : 0.234194
# feature name : making , value : 0.236553
# feature name : select , value : 0.238715
# feature name : live , value : 0.245985
# feature name : recommend , value : 0.247077
# feature name : link , value : 0.258315
# feature name : etc , value : 0.258394
# feature name : see , value : 0.261712
# feature name : insurance card , value : 0.262399
# feature name : around , value : 0.265693
# feature name : add , value : 0.269218

# %%
c=[]
for i in range(0,50):
    c.append(count_vect.get_feature_names()[b[i][0]])
from wordcloud import WordCloud
wordcloud = WordCloud(
                          background_color='white',
                          max_words=100,
                          max_font_size=30, 
                          random_state=50
                         ).generate(str(c))

fig = plt.figure(1,figsize=(20,20))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
